# %%
import matplotlib
matplotlib.use('TkAgg')
from matplotlib import patches
from matplotlib import pyplot as plt
from matplotlib import gridspec as gsp
from matplotlib.widgets import Slider, Button, RadioButtons
from ipywidgets import *

import numpy as np
import csv
import os
import glob
from functools import reduce
import SimpleITK as sitk
from scipy.spatial.distance import cdist

# %%
def get_data(locroot, mtype):
    truthlist = glob.glob(locroot+mtype+'/005/*/predictions/seg-*-tumor.nii')
    truthlist.sort()
    predlist  = glob.glob(locroot+mtype+'/005/*/predictions/pred-*-tumor-masked-int.nii')
    predlist.sort()
    assert len(truthlist) == len(predlist)
    print('Found', len(truthlist), 'segmentations and predictions...')
    return truthlist, predlist

# %%
# archs = ['unet', 'resnet', 'densenet']
# pocket = ['', '-pocket']
# c2Dt = ['', '-c2Dt']
archs = ['densenet']
pocket = ['-pocket']
c2Dt = ['']
modeltypes = []
for a in archs:
    for c in c2Dt:
        for p in pocket:
            modeltypes += [a+p+c]

locroot = '/rsrch1/ip/jacctor/smallnet/tumorhcc-ensemble/densenet-ensemble-512/'
# locroot = '/rsrch1/ip/jacctor/smallnet/tumorhcc-ensemble/e2e-512/'

# %%
def ShowImage(img):
    data = sitk.GetArrayFromImage(img)
    plt.imshow(data)
    plt.show()

# %%
def SliceViewer(data, data2=None):
    img = sitk.GetArrayFromImage(data)
    cmax = np.max(img)
    
    if data2 is not None:
        seg = sitk.GetArrayFromImage(data2)
        cmax = max([cmax, np.max(seg)])

    def f(Slice):
        if data2 is not None:
            fig = plt.figure(figsize=(8,4))
            ax  = fig.add_subplot(121)
        else:
            fig = plt.figure(figsize=(4,4))
            ax  = fig.add_subplot(111)
        img0 = img[...,Slice]
        ax.imshow(img0, cmap="hsv", vmin=0, vmax=cmax)
        if data2 is not None:
            ax = fig.add_subplot(122)
            seg0 = seg[...,Slice]
            ax.imshow(seg0, cmap="hsv", vmin=0, vmax=cmax)
    interact(f, Slice=widgets.IntSlider(min=0, max=img.shape[-1],step=1,value=0))

# %%
###
### true, pred are SITK::Image
### returns hdist_avg, hdist_max, dice, vol_true
###
def GetSITKStats(true, pred):
    
    # Calculate Hausdorff distances
    try:
        hausdorffFilter = sitk.HausdorffDistanceImageFilter()
#         hausdorffFilter.Execute(true, pred)
#         hdist_avg = hausdorffFilter.GetAverageHausdorffDistance()
#         hdist_max = hausdorffFilter.GetHausdorffDistance()
        hdist_avg = None
        hdist_max = None
    except:
        hdist_avg = None
        hdist_max = None
        
    
    # Calculate Dice scores
    try:
        diceFilter = sitk.LabelOverlapMeasuresImageFilter()
        diceFilter.Execute(true, pred)
        dice = diceFilter.GetDiceCoefficient()
    except:
        dice = None
    
    # Calculate true volume statistics
    try:
        stats = sitk.LabelShapeStatisticsImageFilter()
        stats.Execute(true)
        vol_true = stats.GetNumberOfPixels(1)
    except:
        vol_true = None
    
    results = (hdist_avg, hdist_max, dice, vol_true)
    return results

# %%
def closest_node(node, nodes):
    
    min_idx = cdist([node], nodes).argmin()
    return int(min_idx), nodes[min_idx]

def StatsSITK(truth, pred, iii):
    truth = sitk.ReadImage(truth, sitk.sitkUInt8, imageIO="NiftiImageIO")
    pred  = sitk.ReadImage(pred,  sitk.sitkUInt8, imageIO="NiftiImageIO")
    
    global_scores = GetSITKStats(truth, pred)
    individual_scores = {}

    stats = sitk.LabelShapeStatisticsImageFilter()
    stats.Execute(truth)
    if stats.GetNumberOfLabels == 0:
        return global_scores, individual_scores
    
    individual_scores['true_vol']     = []
    individual_scores['closest-dice'] = []
    individual_scores['max-dice']     = []
    individual_scores['hdist_avg']    = []
    individual_scores['hdist_max']    = []
    
    
    connCompFilter      = sitk.ConnectedComponentImageFilter()
    conn_comp_true      = connCompFilter.Execute(truth)
    num_true_components = connCompFilter.GetObjectCount()
    true_centroids      = np.zeros((num_true_components+1, 3))
    print('\t Found', num_true_components, 'regions in true segmentation.')
    
    for idx in range(num_true_components+1):
        this_truth = sitk.BinaryThreshold(conn_comp_true,
                                  lowerThreshold=idx,
                                  upperThreshold=idx+1,
                                  insideValue=1,
                                  outsideValue=0)
        thisStatsFilter = sitk.LabelShapeStatisticsImageFilter()
        thisStatsFilter.Execute(this_truth)
#         print(idx, '\t', thisStatsFilter.GetNumberOfPixels(1), '\t', thisStatsFilter.GetCentroid(1))
        true_centroids[idx,:] = np.array(thisStatsFilter.GetCentroid(1))

        
    connCompFilter      = sitk.ConnectedComponentImageFilter()
    conn_comp_pred      = connCompFilter.Execute(pred)
    num_pred_components = connCompFilter.GetObjectCount()
    pred_centroids      = np.zeros((num_pred_components+1, 3))
    print('\t Found', num_pred_components, 'regions in predicted segmentation.')
    
    for idx in range(num_pred_components+1):
        this_pred = sitk.BinaryThreshold(conn_comp_pred,
                                  lowerThreshold=idx,
                                  upperThreshold=idx+1,
                                  insideValue=1,
                                  outsideValue=0)
        thisStatsFilter = sitk.LabelShapeStatisticsImageFilter()
        thisStatsFilter.Execute(this_pred)
#         print(idx, '\t', thisStatsFilter.GetNumberOfPixels(1), '\t', thisStatsFilter.GetCentroid(1))
        pred_centroids[idx,:] = np.array(thisStatsFilter.GetCentroid(1))

    dsc_matrix  = np.zeros((num_true_components+1, num_pred_components+1))
    closest_idx = np.zeros((num_true_components+1,), dtype=np.int16)
    maxdice_idx = np.zeros((num_true_components+1,), dtype=np.int16)
    for idx in range(num_true_components+1):
        this_truth = sitk.BinaryThreshold(conn_comp_true,
                                  lowerThreshold=idx,
                                  upperThreshold=idx+1,
                                  insideValue=1,
                                  outsideValue=0)
        
        pred_idx, _ = closest_node(true_centroids[idx,:], pred_centroids)
        closest_idx[idx] = pred_idx
        this_pred  = sitk.BinaryThreshold(conn_comp_pred,
                                  lowerThreshold=pred_idx,
                                  upperThreshold=pred_idx+1,
                                  insideValue=1,
                                  outsideValue=0)
        this_tumor_stats = GetSITKStats(this_truth, this_pred)
        individual_scores['hdist_avg']    += [this_tumor_stats[0]]
        individual_scores['hdist_max']    += [this_tumor_stats[1]]
        individual_scores['closest-dice'] += [this_tumor_stats[2]]
        individual_scores['true_vol']     += [this_tumor_stats[3]]
        
        for pred_idx in range(num_pred_components+1):
            this_pred  = sitk.BinaryThreshold(conn_comp_pred,
                                              lowerThreshold=pred_idx,
                                              upperThreshold=pred_idx+1,
                                              insideValue=1,
                                              outsideValue=0)

            this_tumor_stats = GetSITKStats(this_truth, this_pred)
            dsc_matrix[idx, pred_idx] = this_tumor_stats[2]
    
    maxdice_idx = np.argmax(dsc_matrix, axis=-1)
    maxdice     = np.max(dsc_matrix, axis=-1)
    closedice   = np.array( [dsc_matrix[idx, closest_idx[idx]] for idx in range(dsc_matrix.shape[0])])

    print('\t Global dice: {:.4f}'.format(global_scores[2]))
    for idx in range(num_true_components+1):
        print('\t', idx, '\tDice (closest): {:.4f}'.format(closedice[idx]), '\tDice (max): {:.4f}'.format(maxdice[idx]))
    
    gs = gsp.GridSpec(1,3, width_ratios=[num_pred_components+1,1,1])
    fig = plt.figure()
    ax1 = plt.subplot(gs[0])
    ax1.imshow(dsc_matrix, cmap='gray', aspect='equal')
    ax1.title.set_text('matrix')
    for idx in range(num_true_components+1):
        pred_idx = closest_idx[idx]
        max_idx  = maxdice_idx[idx]
        rect = patches.Rectangle((max_idx-0.5,  idx-0.5), 1, 1, edgecolor='g', facecolor="none", linewidth=3)
        ax1.add_patch(rect)
        rect = patches.Rectangle((pred_idx-0.5, idx-0.5), 1, 1, edgecolor='r', facecolor="none", linewidth=3)
        ax1.add_patch(rect)
    
    ax2 = plt.subplot(gs[1])
    ax2.imshow(maxdice[:, np.newaxis],   cmap='gray')
    ax2.title.set_text('max')
    ax2.set_aspect('equal')
    ax2.xaxis.set_visible(False)
    
    ax3 = plt.subplot(gs[2])
    ax3.imshow(closedice[:, np.newaxis], cmap='gray')
    ax3.title.set_text('closest')
    ax3.set_aspect('equal')
    ax3.xaxis.set_visible(False)
    
    plt.savefig('dice-matrices/dice-matrix-'+str(iii)+'.png')
    plt.close()
    plt.clf()
    
    for idx in range(num_true_components+1):
        individual_scores['max-dice'] += [maxdice[idx]]
    
    # filter out the false positives, and recompute global scores
    closest_seg = sitk.Image( *truth.GetSize(), sitk.sitkUInt8)
    for idx in range(1,num_true_components+1):
        this_close_idx = int(closest_idx[idx])
        if this_close_idx != 0:
            this_close_pred = sitk.BinaryThreshold(conn_comp_pred,
                                                lowerThreshold=this_close_idx,
                                                upperThreshold=this_close_idx+1,
                                                insideValue=1,
                                                outsideValue=0)
            closest_seg = sitk.Or(closest_seg, this_close_pred)
    filtered_closest_stats = GetSITKStats(truth, closest_seg)
    print('\t Filtered dice (closest): {:.4f}'.format(filtered_closest_stats[2]))

        
    maxreg_seg  = sitk.Image( *truth.GetSize(), sitk.sitkUInt8)
    for idx in range(1,num_true_components+1):
        this_max_idx = int(maxdice_idx[idx])
        if this_max_idx == 0:
            this_max_idx = int(closest_idx[idx])
        if this_max_idx != 0:
            this_max_pred = sitk.BinaryThreshold(conn_comp_pred,
                                                lowerThreshold=this_max_idx,
                                                upperThreshold=this_max_idx+1,
                                                insideValue=1,
                                                outsideValue=0)
            maxreg_seg = sitk.Or(maxreg_seg, this_max_pred)
    filtered_maxreg_stats  = GetSITKStats(truth, maxreg_seg)
    print('\t Filtered dice     (max): {:.4f}'.format(filtered_maxreg_stats[2]))
    
    filtered_scores = [None]*2
    filtered_scores[0] = filtered_closest_stats[2]
    filtered_scores[1] = filtered_maxreg_stats[2]
    
    return global_scores, individual_scores, filtered_scores

# %%
mtype = modeltypes[0]
print('Model type', mtype)
truthlist, predlist = get_data(locroot, mtype)

# truthlist = truthlist[:25]
# predlist  = predlist[:25]
# Out:
# Model type densenet-pocket
# Found 131 segmentations and predictions...

# %%
print('Calculating Hausdorff distances...')
hdist_avg = [None]*len(truthlist)
hdist_max = [None]*len(truthlist)
label_sizes = [None]*len(truthlist)
total_sizes = [None]*len(truthlist)
dice_scores = [None]*len(truthlist)
dice_max_scores = [None]*len(truthlist)
dice_closest_scores = [None]*len(truthlist)
individual_stats = [None]*len(truthlist)
for idx, (tr, pr) in enumerate(zip(truthlist, predlist)):
    print('Image', idx)
    global_scores, individual_scores, filtered_scores = StatsSITK(tr, pr, idx)
    hdist_avg[idx] = global_scores[0]
    hdist_max[idx] = global_scores[1]
    dice_scores[idx] = global_scores[2]
    total_sizes[idx] = global_scores[3]
    label_sizes[idx] = individual_scores['true_vol']
    individual_stats[idx] = individual_scores
    dice_closest_scores[idx] = filtered_scores[0]
    dice_max_scores[idx] = filtered_scores[1]
# Out:
# Calculating Hausdorff distances...
# Image 0
# 	 Found 11 regions in true segmentation.
# 	 Found 10 regions in predicted segmentation.
# 	 Global dice: 0.3991
# 	 0 	Dice (closest): 0.9999 	Dice (max): 0.9999
# 	 1 	Dice (closest): 0.5699 	Dice (max): 0.5699
# 	 2 	Dice (closest): 0.6416 	Dice (max): 0.6416
# 	 3 	Dice (closest): 0.3314 	Dice (max): 0.3314
# 	 4 	Dice (closest): 0.1847 	Dice (max): 0.4715
# 	 5 	Dice (closest): 0.3483 	Dice (max): 0.3483
# 	 6 	Dice (closest): 0.0000 	Dice (max): 0.2875
# 	 7 	Dice (closest): 0.0000 	Dice (max): 0.0001
# 	 8 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 9 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 10 	Dice (closest): 0.3990 	Dice (max): 0.3990
# 	 11 	Dice (closest): 0.6142 	Dice (max): 0.6142
# 	 Filtered dice (closest): 0.0003
# 	 Filtered dice     (max): 0.4220
# Image 1
# 	 Found 12 regions in true segmentation.
# 	 Found 15 regions in predicted segmentation.
# 	 Global dice: 0.5824
# 	 0 	Dice (closest): 0.9999 	Dice (max): 0.9999
# 	 1 	Dice (closest): 0.7192 	Dice (max): 0.7192
# 	 2 	Dice (closest): 0.7681 	Dice (max): 0.7681
# 	 3 	Dice (closest): 0.4317 	Dice (max): 0.4317
# 	 4 	Dice (closest): 0.4599 	Dice (max): 0.4599
# 	 5 	Dice (closest): 0.2968 	Dice (max): 0.2968
# 	 6 	Dice (closest): 0.2155 	Dice (max): 0.4804
# 	 7 	Dice (closest): 0.4137 	Dice (max): 0.4137
# 	 8 	Dice (closest): 0.5867 	Dice (max): 0.5867
# 	 9 	Dice (closest): 0.4537 	Dice (max): 0.4537
# 	 10 	Dice (closest): 0.1606 	Dice (max): 0.1778
# 	 11 	Dice (closest): 0.5589 	Dice (max): 0.5589
# 	 12 	Dice (closest): 0.5695 	Dice (max): 0.5695
# 	 Filtered dice (closest): 0.5655
# 	 Filtered dice     (max): 0.5883
# Image 2
# 	 Found 6 regions in true segmentation.
# 	 Found 15 regions in predicted segmentation.
# 	 Global dice: 0.4454
# 	 0 	Dice (closest): 0.9998 	Dice (max): 0.9998
# 	 1 	Dice (closest): 0.6257 	Dice (max): 0.6257
# 	 2 	Dice (closest): 0.6850 	Dice (max): 0.6850
# 	 3 	Dice (closest): 0.4827 	Dice (max): 0.4827
# 	 4 	Dice (closest): 0.6093 	Dice (max): 0.6093
# 	 5 	Dice (closest): 0.5968 	Dice (max): 0.5968
# 	 6 	Dice (closest): 0.2794 	Dice (max): 0.2794
# 	 Filtered dice (closest): 0.6932
# 	 Filtered dice     (max): 0.6932
# Image 3
# 	 Found 5 regions in true segmentation.
# 	 Found 27 regions in predicted segmentation.
# 	 Global dice: 0.3854
# 	 0 	Dice (closest): 0.9999 	Dice (max): 0.9999
# 	 1 	Dice (closest): 0.4901 	Dice (max): 0.5605
# 	 2 	Dice (closest): 0.6073 	Dice (max): 0.6313
# 	 3 	Dice (closest): 0.5763 	Dice (max): 0.5763
# 	 4 	Dice (closest): 0.6783 	Dice (max): 0.6783
# 	 5 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.6074
# 	 Filtered dice     (max): 0.6642
# Image 4
# 	 Found 1 regions in true segmentation.
# 	 Found 15 regions in predicted segmentation.
# 	 Global dice: 0.0273
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.2134 	Dice (max): 0.2134
# 	 Filtered dice (closest): 0.2134
# 	 Filtered dice     (max): 0.2134
# Image 5
# 	 Found 9 regions in true segmentation.
# 	 Found 11 regions in predicted segmentation.
# 	 Global dice: 0.0204
# 	 0 	Dice (closest): 0.9999 	Dice (max): 0.9999
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0029
# 	 2 	Dice (closest): 0.0000 	Dice (max): 0.0044
# 	 3 	Dice (closest): 0.0000 	Dice (max): 0.0055
# 	 4 	Dice (closest): 0.0000 	Dice (max): 0.0026
# 	 5 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 6 	Dice (closest): 0.0000 	Dice (max): 0.0002
# 	 7 	Dice (closest): 0.0000 	Dice (max): 0.0002
# 	 8 	Dice (closest): 0.0000 	Dice (max): 0.0121
# 	 9 	Dice (closest): 0.0000 	Dice (max): 0.0121
# 	 Filtered dice (closest): 0.0204
# 	 Filtered dice     (max): 0.0204
# Image 6
# 	 Found 2 regions in true segmentation.
# 	 Found 21 regions in predicted segmentation.
# 	 Global dice: 0.2622
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.5476 	Dice (max): 0.5476
# 	 2 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.5476
# 	 Filtered dice     (max): 0.5476
# Image 7
# 	 Found 6 regions in true segmentation.
# 	 Found 32 regions in predicted segmentation.
# 	 Global dice: 0.0045
# 	 0 	Dice (closest): 0.9995 	Dice (max): 0.9995
# 	 1 	Dice (closest): 0.2759 	Dice (max): 0.2759
# 	 2 	Dice (closest): 0.0037 	Dice (max): 0.0045
# 	 3 	Dice (closest): 0.0045 	Dice (max): 0.0045
# 	 4 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 5 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 6 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.2314
# 	 Filtered dice     (max): 0.2755
# Image 8
# 	 Found 13 regions in true segmentation.
# 	 Found 27 regions in predicted segmentation.
# 	 Global dice: 0.7970
# 	 0 	Dice (closest): 0.9996 	Dice (max): 0.9996
# 	 1 	Dice (closest): 0.0012 	Dice (max): 0.3977
# 	 2 	Dice (closest): 0.2655 	Dice (max): 0.2655
# 	 3 	Dice (closest): 0.8519 	Dice (max): 0.8520
# 	 4 	Dice (closest): 0.8480 	Dice (max): 0.8481
# 	 5 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 6 	Dice (closest): 0.5088 	Dice (max): 0.5105
# 	 7 	Dice (closest): 0.5116 	Dice (max): 0.5133
# 	 8 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 9 	Dice (closest): 0.2609 	Dice (max): 0.2609
# 	 10 	Dice (closest): 0.2614 	Dice (max): 0.2614
# 	 11 	Dice (closest): 0.0001 	Dice (max): 0.0001
# 	 12 	Dice (closest): 0.7679 	Dice (max): 0.7679
# 	 13 	Dice (closest): 0.7681 	Dice (max): 0.7681
# 	 Filtered dice (closest): 0.7688
# 	 Filtered dice     (max): 0.7922
# Image 9
# 	 Found 6 regions in true segmentation.
# 	 Found 11 regions in predicted segmentation.
# 	 Global dice: 0.6684
# 	 0 	Dice (closest): 0.9999 	Dice (max): 0.9999
# 	 1 	Dice (closest): 0.6513 	Dice (max): 0.6513
# 	 2 	Dice (closest): 0.7136 	Dice (max): 0.7136
# 	 3 	Dice (closest): 0.2017 	Dice (max): 0.2017
# 	 4 	Dice (closest): 0.2017 	Dice (max): 0.2017
# 	 5 	Dice (closest): 0.5778 	Dice (max): 0.5824
# 	 6 	Dice (closest): 0.5778 	Dice (max): 0.5824
# 	 Filtered dice (closest): 0.6667
# 	 Filtered dice     (max): 0.6667
# Image 10
# 	 Found 5 regions in true segmentation.
# 	 Found 7 regions in predicted segmentation.
# 	 Global dice: 0.5970
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.6215 	Dice (max): 0.6215
# 	 2 	Dice (closest): 0.6701 	Dice (max): 0.6701
# 	 3 	Dice (closest): 0.3114 	Dice (max): 0.3127
# 	 4 	Dice (closest): 0.4959 	Dice (max): 0.4959
# 	 5 	Dice (closest): 0.5459 	Dice (max): 0.5459
# 	 Filtered dice (closest): 0.6031
# 	 Filtered dice     (max): 0.6031
# Image 11
# 	 Found 7 regions in true segmentation.
# 	 Found 48 regions in predicted segmentation.
# 	 Global dice: 0.0561
# 	 0 	Dice (closest): 0.9998 	Dice (max): 0.9998
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0489
# 	 2 	Dice (closest): 0.0000 	Dice (max): 0.0140
# 	 3 	Dice (closest): 0.0000 	Dice (max): 0.0139
# 	 4 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 5 	Dice (closest): 0.0000 	Dice (max): 0.0004
# 	 6 	Dice (closest): 0.0000 	Dice (max): 0.0017
# 	 7 	Dice (closest): 0.0000 	Dice (max): 0.0014
# 	 Filtered dice (closest): 0.0000
# 	 Filtered dice     (max): 0.0635
# Image 12
# 	 Found 1 regions in true segmentation.
# 	 Found 7 regions in predicted segmentation.
# 	 Global dice: 0.7145
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.7659 	Dice (max): 0.7659
# 	 Filtered dice (closest): 0.7659
# 	 Filtered dice     (max): 0.7659
# Image 13
# 	 Found 6 regions in true segmentation.
# 	 Found 33 regions in predicted segmentation.
# 	 Global dice: 0.0285
# 	 0 	Dice (closest): 0.9999 	Dice (max): 0.9999
# 	 1 	Dice (closest): 0.3693 	Dice (max): 0.3693
# 	 2 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 3 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 4 	Dice (closest): 0.5639 	Dice (max): 0.5639
# 	 5 	Dice (closest): 0.5643 	Dice (max): 0.5643
# 	 6 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.5144
# 	 Filtered dice     (max): 0.5144
# Image 14
# 	 Found 5 regions in true segmentation.
# 	 Found 15 regions in predicted segmentation.
# 	 Global dice: 0.6028
# 	 0 	Dice (closest): 0.9999 	Dice (max): 0.9999
# 	 1 	Dice (closest): 0.4641 	Dice (max): 0.4641
# 	 2 	Dice (closest): 0.5124 	Dice (max): 0.5140
# 	 3 	Dice (closest): 0.5296 	Dice (max): 0.5296
# 	 4 	Dice (closest): 0.6846 	Dice (max): 0.6846
# 	 5 	Dice (closest): 0.6669 	Dice (max): 0.6669
# 	 Filtered dice (closest): 0.6133
# 	 Filtered dice     (max): 0.6141
# Image 15
# 	 Found 1 regions in true segmentation.
# 	 Found 4 regions in predicted segmentation.
# 	 Global dice: 0.5437
# 	 0 	Dice (closest): 0.9999 	Dice (max): 0.9999
# 	 1 	Dice (closest): 0.5684 	Dice (max): 0.5684
# 	 Filtered dice (closest): 0.5684
# 	 Filtered dice     (max): 0.5684
# Image 16
# 	 Found 1 regions in true segmentation.
# 	 Found 26 regions in predicted segmentation.
# 	 Global dice: 0.6253
# 	 0 	Dice (closest): 0.9997 	Dice (max): 0.9997
# 	 1 	Dice (closest): 0.6630 	Dice (max): 0.6664
# 	 Filtered dice (closest): 0.6630
# 	 Filtered dice     (max): 0.6664
# Image 17
# 	 Found 1 regions in true segmentation.
# 	 Found 10 regions in predicted segmentation.
# 	 Global dice: 0.2080
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.4544 	Dice (max): 0.4544
# 	 Filtered dice (closest): 0.4544
# 	 Filtered dice     (max): 0.4544
# Image 18
# 	 Found 1 regions in true segmentation.
# 	 Found 7 regions in predicted segmentation.
# 	 Global dice: 0.3020
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.4929 	Dice (max): 0.4929
# 	 Filtered dice (closest): 0.4929
# 	 Filtered dice     (max): 0.4929
# Image 19
# 	 Found 9 regions in true segmentation.
# 	 Found 5 regions in predicted segmentation.
# 	 Global dice: 0.5838
# 	 0 	Dice (closest): 0.9999 	Dice (max): 0.9999
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 2 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 3 	Dice (closest): 0.2975 	Dice (max): 0.2975
# 	 4 	Dice (closest): 0.2912 	Dice (max): 0.2912
# 	 5 	Dice (closest): 0.0000 	Dice (max): 0.0004
# 	 6 	Dice (closest): 0.0004 	Dice (max): 0.0004
# 	 7 	Dice (closest): 0.6706 	Dice (max): 0.6706
# 	 8 	Dice (closest): 0.6705 	Dice (max): 0.6705
# 	 9 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.0006
# 	 Filtered dice     (max): 0.0006
# Image 20
# 	 Found 1 regions in true segmentation.
# 	 Found 3 regions in predicted segmentation.
# 	 Global dice: 0.7499
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.7891 	Dice (max): 0.7891
# 	 Filtered dice (closest): 0.7891
# 	 Filtered dice     (max): 0.7891
# Image 21
# 	 Found 34 regions in true segmentation.
# 	 Found 11 regions in predicted segmentation.
# 	 Global dice: 0.7874
# 	 0 	Dice (closest): 0.9999 	Dice (max): 0.9999
# 	 1 	Dice (closest): 0.7939 	Dice (max): 0.7939
# 	 2 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 3 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 4 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 5 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 6 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 7 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 8 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 9 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 10 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 11 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 12 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 13 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 14 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 15 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 16 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 17 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 18 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 19 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 20 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 21 	Dice (closest): 0.0001 	Dice (max): 0.0001
# 	 22 	Dice (closest): 0.0001 	Dice (max): 0.0001
# 	 23 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 24 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 25 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 26 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 27 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 28 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 29 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 30 	Dice (closest): 0.6336 	Dice (max): 0.6336
# 	 31 	Dice (closest): 0.6336 	Dice (max): 0.6336
# 	 32 	Dice (closest): 0.0008 	Dice (max): 0.0008
# 	 33 	Dice (closest): 0.0000 	Dice (max): 0.0007
# 	 34 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.0137
# 	 Filtered dice     (max): 0.0137
# Image 22
# 	 Found 1 regions in true segmentation.
# 	 Found 11 regions in predicted segmentation.
# 	 Global dice: 0.0000
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.0000
# 	 Filtered dice     (max): 0.0000
# Image 23
# 	 Found 7 regions in true segmentation.
# 	 Found 15 regions in predicted segmentation.
# 	 Global dice: 0.6795
# 	 0 	Dice (closest): 0.9999 	Dice (max): 0.9999
# 	 1 	Dice (closest): 0.7002 	Dice (max): 0.7002
# 	 2 	Dice (closest): 0.5358 	Dice (max): 0.5358
# 	 3 	Dice (closest): 0.7482 	Dice (max): 0.7482
# 	 4 	Dice (closest): 0.4080 	Dice (max): 0.5542
# 	 5 	Dice (closest): 0.5621 	Dice (max): 0.5621
# 	 6 	Dice (closest): 0.2299 	Dice (max): 0.3222
# 	 7 	Dice (closest): 0.4727 	Dice (max): 0.4727
# 	 Filtered dice (closest): 0.6978
# 	 Filtered dice     (max): 0.6882
# Image 24
# 	 Found 6 regions in true segmentation.
# 	 Found 16 regions in predicted segmentation.
# 	 Global dice: 0.7204
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.6942 	Dice (max): 0.6942
# 	 2 	Dice (closest): 0.7317 	Dice (max): 0.7317
# 	 3 	Dice (closest): 0.6047 	Dice (max): 0.6139
# 	 4 	Dice (closest): 0.4444 	Dice (max): 0.4683
# 	 5 	Dice (closest): 0.1782 	Dice (max): 0.4746
# 	 6 	Dice (closest): 0.3211 	Dice (max): 0.3211
# 	 Filtered dice (closest): 0.7437
# 	 Filtered dice     (max): 0.7458
# Image 25
# 	 Found 7 regions in true segmentation.
# 	 Found 22 regions in predicted segmentation.
# 	 Global dice: 0.5926
# 	 0 	Dice (closest): 0.9999 	Dice (max): 0.9999
# 	 1 	Dice (closest): 0.6750 	Dice (max): 0.6750
# 	 2 	Dice (closest): 0.6125 	Dice (max): 0.6125
# 	 3 	Dice (closest): 0.7693 	Dice (max): 0.7702
# 	 4 	Dice (closest): 0.7474 	Dice (max): 0.7474
# 	 5 	Dice (closest): 0.0000 	Dice (max): 0.2851
# 	 6 	Dice (closest): 0.3039 	Dice (max): 0.4015
# 	 7 	Dice (closest): 0.4439 	Dice (max): 0.4439
# 	 Filtered dice (closest): 0.6664
# 	 Filtered dice     (max): 0.6763
# Image 26
# 	 Found 6 regions in true segmentation.
# 	 Found 13 regions in predicted segmentation.
# 	 Global dice: 0.4514
# 	 0 	Dice (closest): 0.9999 	Dice (max): 0.9999
# 	 1 	Dice (closest): 0.6068 	Dice (max): 0.6068
# 	 2 	Dice (closest): 0.6833 	Dice (max): 0.6833
# 	 3 	Dice (closest): 0.6926 	Dice (max): 0.6926
# 	 4 	Dice (closest): 0.3742 	Dice (max): 0.4645
# 	 5 	Dice (closest): 0.3648 	Dice (max): 0.4501
# 	 6 	Dice (closest): 0.3839 	Dice (max): 0.3839
# 	 Filtered dice (closest): 0.6918
# 	 Filtered dice     (max): 0.7030
# Image 27
# 	 Found 12 regions in true segmentation.
# 	 Found 16 regions in predicted segmentation.
# 	 Global dice: 0.6781
# 	 0 	Dice (closest): 0.9998 	Dice (max): 0.9998
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 2 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 3 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 4 	Dice (closest): 0.8555 	Dice (max): 0.8555
# 	 5 	Dice (closest): 0.8547 	Dice (max): 0.8547
# 	 6 	Dice (closest): 0.6188 	Dice (max): 0.6188
# 	 7 	Dice (closest): 0.6192 	Dice (max): 0.6192
# 	 8 	Dice (closest): 0.6162 	Dice (max): 0.6162
# 	 9 	Dice (closest): 0.5904 	Dice (max): 0.5925
# 	 10 	Dice (closest): 0.3608 	Dice (max): 0.3608
# 	 11 	Dice (closest): 0.1424 	Dice (max): 0.4004
# 	 12 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.6738
# 	 Filtered dice     (max): 0.6694
# Image 28
# 	 Found 7 regions in true segmentation.
# 	 Found 26 regions in predicted segmentation.
# 	 Global dice: 0.4426
# 	 0 	Dice (closest): 0.9977 	Dice (max): 0.9977
# 	 1 	Dice (closest): 0.5450 	Dice (max): 0.5450
# 	 2 	Dice (closest): 0.4038 	Dice (max): 0.4038
# 	 3 	Dice (closest): 0.1348 	Dice (max): 0.2986
# 	 4 	Dice (closest): 0.1490 	Dice (max): 0.3271
# 	 5 	Dice (closest): 0.6087 	Dice (max): 0.6087
# 	 6 	Dice (closest): 0.3551 	Dice (max): 0.4545
# 	 7 	Dice (closest): 0.6705 	Dice (max): 0.6705
# 	 Filtered dice (closest): 0.2819
# 	 Filtered dice     (max): 0.4024
# Image 29
# 	 Found 1 regions in true segmentation.
# 	 Found 1 regions in predicted segmentation.
# 	 Global dice: 0.0000
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.0006 	Dice (max): 0.0006
# 	 Filtered dice (closest): 0.0006
# 	 Filtered dice     (max): 0.0006
# Image 30
# 	 Found 1 regions in true segmentation.
# 	 Found 12 regions in predicted segmentation.
# 	 Global dice: 0.0255
# 	 0 	Dice (closest): 0.9999 	Dice (max): 0.9999
# 	 1 	Dice (closest): 0.0120 	Dice (max): 0.0199
# 	 Filtered dice (closest): 0.0120
# 	 Filtered dice     (max): 0.0199
# Image 31
# 	 Found 8 regions in true segmentation.
# 	 Found 8 regions in predicted segmentation.
# 	 Global dice: 0.5943
# 	 0 	Dice (closest): 0.9999 	Dice (max): 0.9999
# 	 1 	Dice (closest): 0.0866 	Dice (max): 0.0866
# 	 2 	Dice (closest): 0.7098 	Dice (max): 0.7098
# 	 3 	Dice (closest): 0.6479 	Dice (max): 0.6479
# 	 4 	Dice (closest): 0.7794 	Dice (max): 0.7794
# 	 5 	Dice (closest): 0.1673 	Dice (max): 0.1673
# 	 6 	Dice (closest): 0.1341 	Dice (max): 0.1656
# 	 7 	Dice (closest): 0.5047 	Dice (max): 0.5055
# 	 8 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.5943
# 	 Filtered dice     (max): 0.5943
# Image 32
# 	 Found 0 regions in true segmentation.
# 	 Found 0 regions in predicted segmentation.
# 	 Global dice: inf
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 Filtered dice (closest): inf
# 	 Filtered dice     (max): inf
# Image 33
# 	 Found 15 regions in true segmentation.
# 	 Found 21 regions in predicted segmentation.
# 	 Global dice: 0.7111
# 	 0 	Dice (closest): 0.9973 	Dice (max): 0.9973
# 	 1 	Dice (closest): 0.6887 	Dice (max): 0.6997
# 	 2 	Dice (closest): 0.7029 	Dice (max): 0.7029
# 	 3 	Dice (closest): 0.7423 	Dice (max): 0.7423
# 	 4 	Dice (closest): 0.7259 	Dice (max): 0.7259
# 	 5 	Dice (closest): 0.1021 	Dice (max): 0.1021
# 	 6 	Dice (closest): 0.1135 	Dice (max): 0.1135
# 	 7 	Dice (closest): 0.0000 	Dice (max): 0.0001
# 	 8 	Dice (closest): 0.0000 	Dice (max): 0.0001
# 	 9 	Dice (closest): 0.0827 	Dice (max): 0.1665
# 	 10 	Dice (closest): 0.0913 	Dice (max): 0.1829
# 	 11 	Dice (closest): 0.0000 	Dice (max): 0.0001
# 	 12 	Dice (closest): 0.7094 	Dice (max): 0.7094
# 	 13 	Dice (closest): 0.7266 	Dice (max): 0.7266
# 	 14 	Dice (closest): 0.4588 	Dice (max): 0.4588
# 	 15 	Dice (closest): 0.4767 	Dice (max): 0.4767
# 	 Filtered dice (closest): 0.6808
# 	 Filtered dice     (max): 0.6902
# Image 34
# 	 Found 0 regions in true segmentation.
# 	 Found 23 regions in predicted segmentation.
# 	 Global dice: 0.0000
# 	 0 	Dice (closest): 0.9996 	Dice (max): 0.9996
# 	 Filtered dice (closest): inf
# 	 Filtered dice     (max): inf
# Image 35
# 	 Found 4 regions in true segmentation.
# 	 Found 11 regions in predicted segmentation.
# 	 Global dice: 0.0000
# 	 0 	Dice (closest): 0.9994 	Dice (max): 0.9994
# 	 1 	Dice (closest): 0.0007 	Dice (max): 0.0007
# 	 2 	Dice (closest): 0.0000 	Dice (max): 0.0001
# 	 3 	Dice (closest): 0.0000 	Dice (max): 0.0005
# 	 4 	Dice (closest): 0.0000 	Dice (max): 0.0005
# 	 Filtered dice (closest): 0.0013
# 	 Filtered dice     (max): 0.0013
# Image 36
# 	 Found 2 regions in true segmentation.
# 	 Found 6 regions in predicted segmentation.
# 	 Global dice: 0.5135
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.5220 	Dice (max): 0.5220
# 	 2 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.5220
# 	 Filtered dice     (max): 0.5220
# Image 37
# 	 Found 8 regions in true segmentation.
# 	 Found 8 regions in predicted segmentation.
# 	 Global dice: 0.7784
# 	 0 	Dice (closest): 0.9999 	Dice (max): 0.9999
# 	 1 	Dice (closest): 0.4697 	Dice (max): 0.4697
# 	 2 	Dice (closest): 0.7875 	Dice (max): 0.7875
# 	 3 	Dice (closest): 0.8740 	Dice (max): 0.8740
# 	 4 	Dice (closest): 0.8395 	Dice (max): 0.8395
# 	 5 	Dice (closest): 0.7769 	Dice (max): 0.7769
# 	 6 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 7 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 8 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.7950
# 	 Filtered dice     (max): 0.7950
# Image 38
# 	 Found 0 regions in true segmentation.
# 	 Found 1 regions in predicted segmentation.
# 	 Global dice: 0.0000
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 Filtered dice (closest): inf
# 	 Filtered dice     (max): inf
# Image 39
# 	 Found 1 regions in true segmentation.
# 	 Found 14 regions in predicted segmentation.
# 	 Global dice: 0.0014
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.0014 	Dice (max): 0.0102
# 	 Filtered dice (closest): 0.0014
# 	 Filtered dice     (max): 0.0014
# Image 40
# 	 Found 18 regions in true segmentation.
# 	 Found 17 regions in predicted segmentation.
# 	 Global dice: 0.6249
# 	 0 	Dice (closest): 0.9989 	Dice (max): 0.9989
# 	 1 	Dice (closest): 0.0948 	Dice (max): 0.0948
# 	 2 	Dice (closest): 0.7234 	Dice (max): 0.7234
# 	 3 	Dice (closest): 0.8081 	Dice (max): 0.8081
# 	 4 	Dice (closest): 0.0757 	Dice (max): 0.2432
# 	 5 	Dice (closest): 0.3435 	Dice (max): 0.4001
# 	 6 	Dice (closest): 0.4526 	Dice (max): 0.4595
# 	 7 	Dice (closest): 0.0000 	Dice (max): 0.0001
# 	 8 	Dice (closest): 0.0000 	Dice (max): 0.0001
# 	 9 	Dice (closest): 0.0000 	Dice (max): 0.0001
# 	 10 	Dice (closest): 0.3978 	Dice (max): 0.3978
# 	 11 	Dice (closest): 0.2584 	Dice (max): 0.3160
# 	 12 	Dice (closest): 0.0000 	Dice (max): 0.0675
# 	 13 	Dice (closest): 0.0000 	Dice (max): 0.0001
# 	 14 	Dice (closest): 0.0000 	Dice (max): 0.0002
# 	 15 	Dice (closest): 0.0706 	Dice (max): 0.3868
# 	 16 	Dice (closest): 0.4088 	Dice (max): 0.4088
# 	 17 	Dice (closest): 0.0000 	Dice (max): 0.0001
# 	 18 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.6230
# 	 Filtered dice     (max): 0.5384
# Image 41
# 	 Found 0 regions in true segmentation.
# 	 Found 3 regions in predicted segmentation.
# 	 Global dice: 0.0000
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 Filtered dice (closest): inf
# 	 Filtered dice     (max): inf
# Image 42
# 	 Found 2 regions in true segmentation.
# 	 Found 2 regions in predicted segmentation.
# 	 Global dice: 0.0000
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.0001 	Dice (max): 0.0001
# 	 2 	Dice (closest): 0.0001 	Dice (max): 0.0001
# 	 Filtered dice (closest): 0.0001
# 	 Filtered dice     (max): 0.0001
# Image 43
# 	 Found 1 regions in true segmentation.
# 	 Found 21 regions in predicted segmentation.
# 	 Global dice: 0.0004
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0004
# 	 Filtered dice (closest): 0.0000
# 	 Filtered dice     (max): 0.0004
# Image 44
# 	 Found 2 regions in true segmentation.
# 	 Found 9 regions in predicted segmentation.
# 	 Global dice: 0.5356
# 	 0 	Dice (closest): 0.9992 	Dice (max): 0.9992
# 	 1 	Dice (closest): 0.0001 	Dice (max): 0.4608
# 	 2 	Dice (closest): 0.7609 	Dice (max): 0.7609
# 	 Filtered dice (closest): 0.4574
# 	 Filtered dice     (max): 0.4609
# Image 45
# 	 Found 1 regions in true segmentation.
# 	 Found 21 regions in predicted segmentation.
# 	 Global dice: 0.0000
# 	 0 	Dice (closest): 0.9996 	Dice (max): 0.9996
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0005
# 	 Filtered dice (closest): 0.0000
# 	 Filtered dice     (max): 0.0000
# Image 46
# 	 Found 50 regions in true segmentation.
# 	 Found 27 regions in predicted segmentation.
# 	 Global dice: 0.5695
# 	 0 	Dice (closest): 0.9996 	Dice (max): 0.9996
# 	 1 	Dice (closest): 0.1639 	Dice (max): 0.1639
# 	 2 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 3 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 4 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 5 	Dice (closest): 0.0000 	Dice (max): 0.0001
# 	 6 	Dice (closest): 0.0000 	Dice (max): 0.0001
# 	 7 	Dice (closest): 0.2514 	Dice (max): 0.2514
# 	 8 	Dice (closest): 0.4083 	Dice (max): 0.4083
# 	 9 	Dice (closest): 0.5156 	Dice (max): 0.5156
# 	 10 	Dice (closest): 0.2331 	Dice (max): 0.2456
# 	 11 	Dice (closest): 0.0000 	Dice (max): 0.3913
# 	 12 	Dice (closest): 0.5681 	Dice (max): 0.5681
# 	 13 	Dice (closest): 0.4019 	Dice (max): 0.4019
# 	 14 	Dice (closest): 0.4769 	Dice (max): 0.4769
# 	 15 	Dice (closest): 0.5936 	Dice (max): 0.5936
# 	 16 	Dice (closest): 0.1138 	Dice (max): 0.6945
# 	 17 	Dice (closest): 0.4351 	Dice (max): 0.6044
# 	 18 	Dice (closest): 0.5844 	Dice (max): 0.5844
# 	 19 	Dice (closest): 0.4105 	Dice (max): 0.4105
# 	 20 	Dice (closest): 0.0000 	Dice (max): 0.3154
# 	 21 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 22 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 23 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 24 	Dice (closest): 0.5455 	Dice (max): 0.5455
# 	 25 	Dice (closest): 0.0000 	Dice (max): 0.5321
# 	 26 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 27 	Dice (closest): 0.2387 	Dice (max): 0.3257
# 	 28 	Dice (closest): 0.1518 	Dice (max): 0.2094
# 	 29 	Dice (closest): 0.0000 	Dice (max): 0.0001
# 	 30 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 31 	Dice (closest): 0.0000 	Dice (max): 0.1000
# 	 32 	Dice (closest): 0.0531 	Dice (max): 0.0531
# 	 33 	Dice (closest): 0.0000 	Dice (max): 0.6826
# 	 34 	Dice (closest): 0.0000 	Dice (max): 0.6316
# 	 35 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 36 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 37 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 38 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 39 	Dice (closest): 0.3921 	Dice (max): 0.3921
# 	 40 	Dice (closest): 0.4411 	Dice (max): 0.4411
# 	 41 	Dice (closest): 0.0000 	Dice (max): 0.1806
# 	 42 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 43 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 44 	Dice (closest): 0.3252 	Dice (max): 0.3252
# 	 45 	Dice (closest): 0.2541 	Dice (max): 0.2541
# 	 46 	Dice (closest): 0.5701 	Dice (max): 0.5820
# 	 47 	Dice (closest): 0.6682 	Dice (max): 0.6682
# 	 48 	Dice (closest): 0.2703 	Dice (max): 0.2703
# 	 49 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 50 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.0025
# 	 Filtered dice     (max): 0.0025
# Image 47
# 	 Found 0 regions in true segmentation.
# 	 Found 1 regions in predicted segmentation.
# 	 Global dice: 0.0000
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 Filtered dice (closest): inf
# 	 Filtered dice     (max): inf
# Image 48
# 	 Found 4 regions in true segmentation.
# 	 Found 2 regions in predicted segmentation.
# 	 Global dice: 0.8027
# 	 0 	Dice (closest): 0.9997 	Dice (max): 0.9997
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 2 	Dice (closest): 0.8150 	Dice (max): 0.8150
# 	 3 	Dice (closest): 0.8084 	Dice (max): 0.8084
# 	 4 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.0011
# 	 Filtered dice     (max): 0.0011
# Image 49
# 	 Found 22 regions in true segmentation.
# 	 Found 4 regions in predicted segmentation.
# 	 Global dice: 0.5951
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 2 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 3 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 4 	Dice (closest): 0.7604 	Dice (max): 0.7604
# 	 5 	Dice (closest): 0.7397 	Dice (max): 0.7397
# 	 6 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 7 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 8 	Dice (closest): 0.6394 	Dice (max): 0.6394
# 	 9 	Dice (closest): 0.6426 	Dice (max): 0.6426
# 	 10 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 11 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 12 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 13 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 14 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 15 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 16 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 17 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 18 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 19 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 20 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 21 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 22 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.0002
# 	 Filtered dice     (max): 0.0002
# Image 50
# 	 Found 1 regions in true segmentation.
# 	 Found 1 regions in predicted segmentation.
# 	 Global dice: 0.7332
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.7332 	Dice (max): 0.7332
# 	 Filtered dice (closest): 0.7332
# 	 Filtered dice     (max): 0.7332
# Image 51
# 	 Found 11 regions in true segmentation.
# 	 Found 17 regions in predicted segmentation.
# 	 Global dice: 0.5347
# 	 0 	Dice (closest): 0.9993 	Dice (max): 0.9993
# 	 1 	Dice (closest): 0.6662 	Dice (max): 0.6662
# 	 2 	Dice (closest): 0.3953 	Dice (max): 0.3953
# 	 3 	Dice (closest): 0.2230 	Dice (max): 0.2627
# 	 4 	Dice (closest): 0.2442 	Dice (max): 0.2952
# 	 5 	Dice (closest): 0.5390 	Dice (max): 0.5390
# 	 6 	Dice (closest): 0.4642 	Dice (max): 0.4642
# 	 7 	Dice (closest): 0.6292 	Dice (max): 0.6292
# 	 8 	Dice (closest): 0.5899 	Dice (max): 0.5899
# 	 9 	Dice (closest): 0.0201 	Dice (max): 0.0201
# 	 10 	Dice (closest): 0.7683 	Dice (max): 0.7683
# 	 11 	Dice (closest): 0.7684 	Dice (max): 0.7684
# 	 Filtered dice (closest): 0.5296
# 	 Filtered dice     (max): 0.4602
# Image 52
# 	 Found 2 regions in true segmentation.
# 	 Found 1 regions in predicted segmentation.
# 	 Global dice: 0.2160
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.2160 	Dice (max): 0.2160
# 	 2 	Dice (closest): 0.0000 	Dice (max): 0.0001
# 	 Filtered dice (closest): 0.2160
# 	 Filtered dice     (max): 0.2160
# Image 53
# 	 Found 2 regions in true segmentation.
# 	 Found 5 regions in predicted segmentation.
# 	 Global dice: 0.3603
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.3937 	Dice (max): 0.3937
# 	 2 	Dice (closest): 0.4674 	Dice (max): 0.4674
# 	 Filtered dice (closest): 0.3937
# 	 Filtered dice     (max): 0.3937
# Image 54
# 	 Found 1 regions in true segmentation.
# 	 Found 4 regions in predicted segmentation.
# 	 Global dice: 0.0000
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.0000
# 	 Filtered dice     (max): 0.0000
# Image 55
# 	 Found 1 regions in true segmentation.
# 	 Found 40 regions in predicted segmentation.
# 	 Global dice: 0.0305
# 	 0 	Dice (closest): 0.9998 	Dice (max): 0.9998
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0489
# 	 Filtered dice (closest): 0.0000
# 	 Filtered dice     (max): 0.0489
# Image 56
# 	 Found 2 regions in true segmentation.
# 	 Found 29 regions in predicted segmentation.
# 	 Global dice: 0.8234
# 	 0 	Dice (closest): 0.9994 	Dice (max): 0.9994
# 	 1 	Dice (closest): 0.7772 	Dice (max): 0.7772
# 	 2 	Dice (closest): 0.8308 	Dice (max): 0.8308
# 	 Filtered dice (closest): 0.7772
# 	 Filtered dice     (max): 0.7772
# Image 57
# 	 Found 2 regions in true segmentation.
# 	 Found 8 regions in predicted segmentation.
# 	 Global dice: 0.7780
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.7714 	Dice (max): 0.7714
# 	 2 	Dice (closest): 0.6937 	Dice (max): 0.6937
# 	 Filtered dice (closest): 0.8135
# 	 Filtered dice     (max): 0.8135
# Image 58
# 	 Found 5 regions in true segmentation.
# 	 Found 2 regions in predicted segmentation.
# 	 Global dice: 0.0012
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.0038 	Dice (max): 0.0038
# 	 2 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 3 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 4 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 5 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.0012
# 	 Filtered dice     (max): 0.0012
# Image 59
# 	 Found 1 regions in true segmentation.
# 	 Found 5 regions in predicted segmentation.
# 	 Global dice: 0.0000
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.0000
# 	 Filtered dice     (max): 0.0000
# Image 60
# 	 Found 1 regions in true segmentation.
# 	 Found 6 regions in predicted segmentation.
# 	 Global dice: 0.7376
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.8201 	Dice (max): 0.8201
# 	 Filtered dice (closest): 0.8201
# 	 Filtered dice     (max): 0.8201
# Image 61
# 	 Found 2 regions in true segmentation.
# 	 Found 8 regions in predicted segmentation.
# 	 Global dice: 0.3557
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.6357 	Dice (max): 0.6357
# 	 2 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.6357
# 	 Filtered dice     (max): 0.6357
# Image 62
# 	 Found 2 regions in true segmentation.
# 	 Found 7 regions in predicted segmentation.
# 	 Global dice: 0.5324
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.6260 	Dice (max): 0.6260
# 	 2 	Dice (closest): 0.6500 	Dice (max): 0.6500
# 	 Filtered dice (closest): 0.6260
# 	 Filtered dice     (max): 0.6260
# Image 63
# 	 Found 5 regions in true segmentation.
# 	 Found 0 regions in predicted segmentation.
# 	 Global dice: 0.0000
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 2 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 3 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 4 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 5 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.0001
# 	 Filtered dice     (max): 0.0001
# Image 64
# 	 Found 1 regions in true segmentation.
# 	 Found 24 regions in predicted segmentation.
# 	 Global dice: 0.8500
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.8513 	Dice (max): 0.8513
# 	 Filtered dice (closest): 0.8513
# 	 Filtered dice     (max): 0.8513
# Image 65
# 	 Found 1 regions in true segmentation.
# 	 Found 19 regions in predicted segmentation.
# 	 Global dice: 0.0821
# 	 0 	Dice (closest): 0.9999 	Dice (max): 0.9999
# 	 1 	Dice (closest): 0.5888 	Dice (max): 0.5888
# 	 Filtered dice (closest): 0.5888
# 	 Filtered dice     (max): 0.5888
# Image 66
# 	 Found 5 regions in true segmentation.
# 	 Found 10 regions in predicted segmentation.
# 	 Global dice: 0.1945
# 	 0 	Dice (closest): 0.9999 	Dice (max): 0.9999
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.2065
# 	 2 	Dice (closest): 0.2700 	Dice (max): 0.2700
# 	 3 	Dice (closest): 0.4743 	Dice (max): 0.4743
# 	 4 	Dice (closest): 0.5691 	Dice (max): 0.5691
# 	 5 	Dice (closest): 0.6242 	Dice (max): 0.6242
# 	 Filtered dice (closest): 0.2346
# 	 Filtered dice     (max): 0.3120
# Image 67
# 	 Found 1 regions in true segmentation.
# 	 Found 2 regions in predicted segmentation.
# 	 Global dice: 0.0000
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.0000
# 	 Filtered dice     (max): 0.0000
# Image 68
# 	 Found 1 regions in true segmentation.
# 	 Found 37 regions in predicted segmentation.
# 	 Global dice: 0.0549
# 	 0 	Dice (closest): 0.9990 	Dice (max): 0.9990
# 	 1 	Dice (closest): 0.8508 	Dice (max): 0.8516
# 	 Filtered dice (closest): 0.8508
# 	 Filtered dice     (max): 0.8516
# Image 69
# 	 Found 1 regions in true segmentation.
# 	 Found 3 regions in predicted segmentation.
# 	 Global dice: 0.7915
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.8168 	Dice (max): 0.8168
# 	 Filtered dice (closest): 0.8168
# 	 Filtered dice     (max): 0.8168
# Image 70
# 	 Found 3 regions in true segmentation.
# 	 Found 43 regions in predicted segmentation.
# 	 Global dice: 0.8260
# 	 0 	Dice (closest): 0.9997 	Dice (max): 0.9997
# 	 1 	Dice (closest): 0.7076 	Dice (max): 0.7111
# 	 2 	Dice (closest): 0.8734 	Dice (max): 0.8734
# 	 3 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.7051
# 	 Filtered dice     (max): 0.7086
# Image 71
# 	 Found 7 regions in true segmentation.
# 	 Found 24 regions in predicted segmentation.
# 	 Global dice: 0.3779
# 	 0 	Dice (closest): 0.9991 	Dice (max): 0.9991
# 	 1 	Dice (closest): 0.3562 	Dice (max): 0.3604
# 	 2 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 3 	Dice (closest): 0.8486 	Dice (max): 0.8486
# 	 4 	Dice (closest): 0.5747 	Dice (max): 0.5747
# 	 5 	Dice (closest): 0.7236 	Dice (max): 0.7236
# 	 6 	Dice (closest): 0.0057 	Dice (max): 0.0057
# 	 7 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.3865
# 	 Filtered dice     (max): 0.3903
# Image 72
# 	 Found 4 regions in true segmentation.
# 	 Found 12 regions in predicted segmentation.
# 	 Global dice: 0.6165
# 	 0 	Dice (closest): 0.9997 	Dice (max): 0.9997
# 	 1 	Dice (closest): 0.7177 	Dice (max): 0.7177
# 	 2 	Dice (closest): 0.7409 	Dice (max): 0.7409
# 	 3 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 4 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.7105
# 	 Filtered dice     (max): 0.7105
# Image 73
# 	 Found 1 regions in true segmentation.
# 	 Found 5 regions in predicted segmentation.
# 	 Global dice: 0.0000
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.0000
# 	 Filtered dice     (max): 0.0000
# Image 74
# 	 Found 2 regions in true segmentation.
# 	 Found 28 regions in predicted segmentation.
# 	 Global dice: 0.0521
# 	 0 	Dice (closest): 0.9987 	Dice (max): 0.9987
# 	 1 	Dice (closest): 0.1248 	Dice (max): 0.1248
# 	 2 	Dice (closest): 0.8110 	Dice (max): 0.8110
# 	 Filtered dice (closest): 0.1417
# 	 Filtered dice     (max): 0.1417
# Image 75
# 	 Found 4 regions in true segmentation.
# 	 Found 10 regions in predicted segmentation.
# 	 Global dice: 0.0738
# 	 0 	Dice (closest): 0.9998 	Dice (max): 0.9998
# 	 1 	Dice (closest): 0.3802 	Dice (max): 0.3802
# 	 2 	Dice (closest): 0.2043 	Dice (max): 0.3067
# 	 3 	Dice (closest): 0.0891 	Dice (max): 0.3096
# 	 4 	Dice (closest): 0.3405 	Dice (max): 0.3405
# 	 Filtered dice (closest): 0.3208
# 	 Filtered dice     (max): 0.3208
# Image 76
# 	 Found 10 regions in true segmentation.
# 	 Found 58 regions in predicted segmentation.
# 	 Global dice: 0.7421
# 	 0 	Dice (closest): 0.9990 	Dice (max): 0.9990
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.6387
# 	 2 	Dice (closest): 0.6935 	Dice (max): 0.6935
# 	 3 	Dice (closest): 0.8267 	Dice (max): 0.8267
# 	 4 	Dice (closest): 0.5927 	Dice (max): 0.5929
# 	 5 	Dice (closest): 0.6372 	Dice (max): 0.6564
# 	 6 	Dice (closest): 0.0328 	Dice (max): 0.6835
# 	 7 	Dice (closest): 0.0000 	Dice (max): 0.6485
# 	 8 	Dice (closest): 0.8623 	Dice (max): 0.8623
# 	 9 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 10 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.7125
# 	 Filtered dice     (max): 0.7029
# Image 77
# 	 Found 2 regions in true segmentation.
# 	 Found 3 regions in predicted segmentation.
# 	 Global dice: 0.1259
# 	 0 	Dice (closest): 0.9999 	Dice (max): 0.9999
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.1271
# 	 2 	Dice (closest): 0.0000 	Dice (max): 0.0003
# 	 Filtered dice (closest): 0.0000
# 	 Filtered dice     (max): 0.1259
# Image 78
# 	 Found 14 regions in true segmentation.
# 	 Found 22 regions in predicted segmentation.
# 	 Global dice: 0.5660
# 	 0 	Dice (closest): 0.9999 	Dice (max): 0.9999
# 	 1 	Dice (closest): 0.5904 	Dice (max): 0.5904
# 	 2 	Dice (closest): 0.8374 	Dice (max): 0.8374
# 	 3 	Dice (closest): 0.0000 	Dice (max): 0.5296
# 	 4 	Dice (closest): 0.6956 	Dice (max): 0.6956
# 	 5 	Dice (closest): 0.0000 	Dice (max): 0.6577
# 	 6 	Dice (closest): 0.7084 	Dice (max): 0.7084
# 	 7 	Dice (closest): 0.5287 	Dice (max): 0.5287
# 	 8 	Dice (closest): 0.5659 	Dice (max): 0.6067
# 	 9 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 10 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 11 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 12 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 13 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 14 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.5993
# 	 Filtered dice     (max): 0.6036
# Image 79
# 	 Found 11 regions in true segmentation.
# 	 Found 64 regions in predicted segmentation.
# 	 Global dice: 0.6361
# 	 0 	Dice (closest): 0.9978 	Dice (max): 0.9978
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.5893
# 	 2 	Dice (closest): 0.7649 	Dice (max): 0.7649
# 	 3 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 4 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 5 	Dice (closest): 0.3623 	Dice (max): 0.3623
# 	 6 	Dice (closest): 0.2896 	Dice (max): 0.2896
# 	 7 	Dice (closest): 0.1185 	Dice (max): 0.2144
# 	 8 	Dice (closest): 0.0470 	Dice (max): 0.0945
# 	 9 	Dice (closest): 0.0000 	Dice (max): 0.0018
# 	 10 	Dice (closest): 0.0018 	Dice (max): 0.1431
# 	 11 	Dice (closest): 0.2689 	Dice (max): 0.2689
# 	 Filtered dice (closest): 0.5885
# 	 Filtered dice     (max): 0.5885
# Image 80
# 	 Found 20 regions in true segmentation.
# 	 Found 47 regions in predicted segmentation.
# 	 Global dice: 0.4560
# 	 0 	Dice (closest): 0.9992 	Dice (max): 0.9992
# 	 1 	Dice (closest): 0.2159 	Dice (max): 0.2159
# 	 2 	Dice (closest): 0.2246 	Dice (max): 0.2246
# 	 3 	Dice (closest): 0.7895 	Dice (max): 0.7895
# 	 4 	Dice (closest): 0.7897 	Dice (max): 0.7897
# 	 5 	Dice (closest): 0.5659 	Dice (max): 0.5659
# 	 6 	Dice (closest): 0.5659 	Dice (max): 0.5659
# 	 7 	Dice (closest): 0.6100 	Dice (max): 0.6100
# 	 8 	Dice (closest): 0.6102 	Dice (max): 0.6102
# 	 9 	Dice (closest): 0.0574 	Dice (max): 0.2535
# 	 10 	Dice (closest): 0.0553 	Dice (max): 0.2456
# 	 11 	Dice (closest): 0.8283 	Dice (max): 0.8283
# 	 12 	Dice (closest): 0.0716 	Dice (max): 0.0811
# 	 13 	Dice (closest): 0.0716 	Dice (max): 0.0811
# 	 14 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 15 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 16 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 17 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 18 	Dice (closest): 0.0000 	Dice (max): 0.0002
# 	 19 	Dice (closest): 0.0000 	Dice (max): 0.0002
# 	 20 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.3668
# 	 Filtered dice     (max): 0.3793
# Image 81
# 	 Found 1 regions in true segmentation.
# 	 Found 22 regions in predicted segmentation.
# 	 Global dice: 0.2645
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.2740 	Dice (max): 0.2740
# 	 Filtered dice (closest): 0.2740
# 	 Filtered dice     (max): 0.2740
# Image 82
# 	 Found 2 regions in true segmentation.
# 	 Found 3 regions in predicted segmentation.
# 	 Global dice: 0.4698
# 	 0 	Dice (closest): 0.9998 	Dice (max): 0.9998
# 	 1 	Dice (closest): 0.4691 	Dice (max): 0.4691
# 	 2 	Dice (closest): 0.4706 	Dice (max): 0.4706
# 	 Filtered dice (closest): 0.4691
# 	 Filtered dice     (max): 0.4691
# Image 83
# 	 Found 10 regions in true segmentation.
# 	 Found 8 regions in predicted segmentation.
# 	 Global dice: 0.0004
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.0027 	Dice (max): 0.0027
# 	 2 	Dice (closest): 0.0001 	Dice (max): 0.0001
# 	 3 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 4 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 5 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 6 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 7 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 8 	Dice (closest): 0.0000 	Dice (max): 0.0669
# 	 9 	Dice (closest): 0.1598 	Dice (max): 0.2042
# 	 10 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.0027
# 	 Filtered dice     (max): 0.0027
# Image 84
# 	 Found 10 regions in true segmentation.
# 	 Found 10 regions in predicted segmentation.
# 	 Global dice: 0.5727
# 	 0 	Dice (closest): 0.9999 	Dice (max): 0.9999
# 	 1 	Dice (closest): 0.6686 	Dice (max): 0.7017
# 	 2 	Dice (closest): 0.8128 	Dice (max): 0.8128
# 	 3 	Dice (closest): 0.0785 	Dice (max): 0.0785
# 	 4 	Dice (closest): 0.6610 	Dice (max): 0.6610
# 	 5 	Dice (closest): 0.7342 	Dice (max): 0.7342
# 	 6 	Dice (closest): 0.0000 	Dice (max): 0.3128
# 	 7 	Dice (closest): 0.5608 	Dice (max): 0.5608
# 	 8 	Dice (closest): 0.3881 	Dice (max): 0.5076
# 	 9 	Dice (closest): 0.4384 	Dice (max): 0.4384
# 	 10 	Dice (closest): 0.4773 	Dice (max): 0.4773
# 	 Filtered dice (closest): 0.6000
# 	 Filtered dice     (max): 0.6138
# Image 85
# 	 Found 2 regions in true segmentation.
# 	 Found 11 regions in predicted segmentation.
# 	 Global dice: 0.5755
# 	 0 	Dice (closest): 0.9995 	Dice (max): 0.9995
# 	 1 	Dice (closest): 0.5475 	Dice (max): 0.5475
# 	 2 	Dice (closest): 0.5637 	Dice (max): 0.5637
# 	 Filtered dice (closest): 0.5475
# 	 Filtered dice     (max): 0.5475
# Image 86
# 	 Found 1 regions in true segmentation.
# 	 Found 7 regions in predicted segmentation.
# 	 Global dice: 0.7364
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.8167 	Dice (max): 0.8167
# 	 Filtered dice (closest): 0.8167
# 	 Filtered dice     (max): 0.8167
# Image 87
# 	 Found 1 regions in true segmentation.
# 	 Found 35 regions in predicted segmentation.
# 	 Global dice: 0.7136
# 	 0 	Dice (closest): 0.9996 	Dice (max): 0.9996
# 	 1 	Dice (closest): 0.3647 	Dice (max): 0.5267
# 	 Filtered dice (closest): 0.3647
# 	 Filtered dice     (max): 0.5267
# Image 88
# 	 Found 1 regions in true segmentation.
# 	 Found 0 regions in predicted segmentation.
# 	 Global dice: 0.0000
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.0000
# 	 Filtered dice     (max): 0.0000
# Image 89
# 	 Found 14 regions in true segmentation.
# 	 Found 112 regions in predicted segmentation.
# 	 Global dice: 0.1886
# 	 0 	Dice (closest): 0.9989 	Dice (max): 0.9989
# 	 1 	Dice (closest): 0.0009 	Dice (max): 0.0434
# 	 2 	Dice (closest): 0.0007 	Dice (max): 0.0980
# 	 3 	Dice (closest): 0.0043 	Dice (max): 0.1172
# 	 4 	Dice (closest): 0.1168 	Dice (max): 0.1168
# 	 5 	Dice (closest): 0.1145 	Dice (max): 0.1145
# 	 6 	Dice (closest): 0.0000 	Dice (max): 0.0565
# 	 7 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 8 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 9 	Dice (closest): 0.0616 	Dice (max): 0.1649
# 	 10 	Dice (closest): 0.0507 	Dice (max): 0.1419
# 	 11 	Dice (closest): 0.0459 	Dice (max): 0.2107
# 	 12 	Dice (closest): 0.0367 	Dice (max): 0.2769
# 	 13 	Dice (closest): 0.0218 	Dice (max): 0.0652
# 	 14 	Dice (closest): 0.0180 	Dice (max): 0.0231
# 	 Filtered dice (closest): 0.0301
# 	 Filtered dice     (max): 0.1058
# Image 90
# 	 Found 2 regions in true segmentation.
# 	 Found 15 regions in predicted segmentation.
# 	 Global dice: 0.0000
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0002
# 	 2 	Dice (closest): 0.0001 	Dice (max): 0.0001
# 	 Filtered dice (closest): 0.0002
# 	 Filtered dice     (max): 0.0002
# Image 91
# 	 Found 2 regions in true segmentation.
# 	 Found 4 regions in predicted segmentation.
# 	 Global dice: 0.0009
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.0010 	Dice (max): 0.0010
# 	 2 	Dice (closest): 0.0010 	Dice (max): 0.0010
# 	 Filtered dice (closest): 0.0010
# 	 Filtered dice     (max): 0.0010
# Image 92
# 	 Found 0 regions in true segmentation.
# 	 Found 3 regions in predicted segmentation.
# 	 Global dice: 0.0000
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 Filtered dice (closest): inf
# 	 Filtered dice     (max): inf
# Image 93
# 	 Found 7 regions in true segmentation.
# 	 Found 30 regions in predicted segmentation.
# 	 Global dice: 0.2807
# 	 0 	Dice (closest): 0.9995 	Dice (max): 0.9995
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 2 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 3 	Dice (closest): 0.1496 	Dice (max): 0.1496
# 	 4 	Dice (closest): 0.1495 	Dice (max): 0.1495
# 	 5 	Dice (closest): 0.0279 	Dice (max): 0.0279
# 	 6 	Dice (closest): 0.0232 	Dice (max): 0.0232
# 	 7 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.1482
# 	 Filtered dice     (max): 0.1482
# Image 94
# 	 Found 0 regions in true segmentation.
# 	 Found 2 regions in predicted segmentation.
# 	 Global dice: 0.0000
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 Filtered dice (closest): inf
# 	 Filtered dice     (max): inf
# Image 95
# 	 Found 8 regions in true segmentation.
# 	 Found 34 regions in predicted segmentation.
# 	 Global dice: 0.3522
# 	 0 	Dice (closest): 0.9997 	Dice (max): 0.9997
# 	 1 	Dice (closest): 0.0257 	Dice (max): 0.1523
# 	 2 	Dice (closest): 0.2275 	Dice (max): 0.3138
# 	 3 	Dice (closest): 0.2266 	Dice (max): 0.3127
# 	 4 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 5 	Dice (closest): 0.0488 	Dice (max): 0.1645
# 	 6 	Dice (closest): 0.0470 	Dice (max): 0.1587
# 	 7 	Dice (closest): 0.1552 	Dice (max): 0.1673
# 	 8 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.1050
# 	 Filtered dice     (max): 0.2140
# Image 96
# 	 Found 0 regions in true segmentation.
# 	 Found 3 regions in predicted segmentation.
# 	 Global dice: 0.0000
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 Filtered dice (closest): inf
# 	 Filtered dice     (max): inf
# Image 97
# 	 Found 9 regions in true segmentation.
# 	 Found 0 regions in predicted segmentation.
# 	 Global dice: 0.0000
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 2 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 3 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 4 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 5 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 6 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 7 	Dice (closest): 0.0000 	Dice (max): 0.0000
# ...
# 	 13 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 14 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 15 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 16 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 17 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 18 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 19 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 20 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 21 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 22 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 23 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 24 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 25 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 26 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 27 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 28 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 29 	Dice (closest): 0.2253 	Dice (max): 0.2342
# 	 30 	Dice (closest): 0.2253 	Dice (max): 0.2341
# 	 31 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 32 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 33 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 34 	Dice (closest): 0.0731 	Dice (max): 0.0731
# 	 35 	Dice (closest): 0.0731 	Dice (max): 0.0731
# 	 36 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 37 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 38 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 39 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 40 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 41 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 42 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 43 	Dice (closest): 0.0263 	Dice (max): 0.0263
# 	 44 	Dice (closest): 0.0263 	Dice (max): 0.0263
# 	 45 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 46 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 47 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 48 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 49 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 50 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 51 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 52 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 53 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 54 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 55 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 56 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 57 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 58 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 59 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 60 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 61 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 62 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 63 	Dice (closest): 0.3996 	Dice (max): 0.3996
# 	 64 	Dice (closest): 0.2176 	Dice (max): 0.3867
# 	 65 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.1685
# 	 Filtered dice     (max): 0.1712
# Image 114
# 	 Found 0 regions in true segmentation.
# 	 Found 0 regions in predicted segmentation.
# 	 Global dice: inf
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 Filtered dice (closest): inf
# 	 Filtered dice     (max): inf
# Image 115
# 	 Found 0 regions in true segmentation.
# 	 Found 2 regions in predicted segmentation.
# 	 Global dice: 0.0000
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 Filtered dice (closest): inf
# 	 Filtered dice     (max): inf
# Image 116
# 	 Found 1 regions in true segmentation.
# 	 Found 0 regions in predicted segmentation.
# 	 Global dice: 0.0000
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.0051 	Dice (max): 0.0051
# 	 Filtered dice (closest): 0.0051
# 	 Filtered dice     (max): 0.0051
# Image 117
# 	 Found 79 regions in true segmentation.
# 	 Found 95 regions in predicted segmentation.
# 	 Global dice: 0.3930
# 	 0 	Dice (closest): 0.9986 	Dice (max): 0.9986
# 	 1 	Dice (closest): 0.0132 	Dice (max): 0.1661
# 	 2 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 3 	Dice (closest): 0.0000 	Dice (max): 0.0847
# 	 4 	Dice (closest): 0.0000 	Dice (max): 0.1135
# 	 5 	Dice (closest): 0.6511 	Dice (max): 0.6511
# 	 6 	Dice (closest): 0.6489 	Dice (max): 0.6489
# 	 7 	Dice (closest): 0.3120 	Dice (max): 0.3120
# 	 8 	Dice (closest): 0.5344 	Dice (max): 0.5344
# 	 9 	Dice (closest): 0.5559 	Dice (max): 0.5559
# 	 10 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 11 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 12 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 13 	Dice (closest): 0.3299 	Dice (max): 0.3299
# 	 14 	Dice (closest): 0.5350 	Dice (max): 0.5350
# 	 15 	Dice (closest): 0.2763 	Dice (max): 0.4459
# 	 16 	Dice (closest): 0.0000 	Dice (max): 0.5302
# 	 17 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 18 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 19 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 20 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 21 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 22 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 23 	Dice (closest): 0.3826 	Dice (max): 0.3826
# 	 24 	Dice (closest): 0.3894 	Dice (max): 0.3894
# 	 25 	Dice (closest): 0.2998 	Dice (max): 0.3461
# 	 26 	Dice (closest): 0.0000 	Dice (max): 0.2267
# 	 27 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 28 	Dice (closest): 0.4330 	Dice (max): 0.4330
# 	 29 	Dice (closest): 0.4473 	Dice (max): 0.6295
# 	 30 	Dice (closest): 0.6833 	Dice (max): 0.6833
# 	 31 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 32 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 33 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 34 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 35 	Dice (closest): 0.0000 	Dice (max): 0.3371
# 	 36 	Dice (closest): 0.5336 	Dice (max): 0.5336
# 	 37 	Dice (closest): 0.5403 	Dice (max): 0.5403
# 	 38 	Dice (closest): 0.0000 	Dice (max): 0.6937
# 	 39 	Dice (closest): 0.7291 	Dice (max): 0.7291
# 	 40 	Dice (closest): 0.0000 	Dice (max): 0.1045
# 	 41 	Dice (closest): 0.5731 	Dice (max): 0.5731
# 	 42 	Dice (closest): 0.6077 	Dice (max): 0.6077
# 	 43 	Dice (closest): 0.3599 	Dice (max): 0.3599
# 	 44 	Dice (closest): 0.6555 	Dice (max): 0.6555
# 	 45 	Dice (closest): 0.2915 	Dice (max): 0.2915
# 	 46 	Dice (closest): 0.0003 	Dice (max): 0.3341
# 	 47 	Dice (closest): 0.0000 	Dice (max): 0.0933
# 	 48 	Dice (closest): 0.0000 	Dice (max): 0.0733
# 	 49 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 50 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 51 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 52 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 53 	Dice (closest): 0.0400 	Dice (max): 0.3167
# 	 54 	Dice (closest): 0.0406 	Dice (max): 0.3205
# 	 55 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 56 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 57 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 58 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 59 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 60 	Dice (closest): 0.0794 	Dice (max): 0.0794
# 	 61 	Dice (closest): 0.1200 	Dice (max): 0.1200
# 	 62 	Dice (closest): 0.1253 	Dice (max): 0.1253
# 	 63 	Dice (closest): 0.0349 	Dice (max): 0.1166
# 	 64 	Dice (closest): 0.0350 	Dice (max): 0.1170
# 	 65 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 66 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 67 	Dice (closest): 0.3051 	Dice (max): 0.3051
# 	 68 	Dice (closest): 0.3240 	Dice (max): 0.3240
# 	 69 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 70 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 71 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 72 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 73 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 74 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 75 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 76 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 77 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 78 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 79 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.2753
# 	 Filtered dice     (max): 0.2879
# Image 118
# 	 Found 11 regions in true segmentation.
# 	 Found 38 regions in predicted segmentation.
# 	 Global dice: 0.1883
# 	 0 	Dice (closest): 0.9983 	Dice (max): 0.9983
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 2 	Dice (closest): 0.0068 	Dice (max): 0.0524
# 	 3 	Dice (closest): 0.0068 	Dice (max): 0.0524
# 	 4 	Dice (closest): 0.0000 	Dice (max): 0.0780
# 	 5 	Dice (closest): 0.0000 	Dice (max): 0.0632
# 	 6 	Dice (closest): 0.0163 	Dice (max): 0.0163
# 	 7 	Dice (closest): 0.0173 	Dice (max): 0.0173
# 	 8 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 9 	Dice (closest): 0.0000 	Dice (max): 0.5656
# 	 10 	Dice (closest): 0.6260 	Dice (max): 0.6260
# 	 11 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.0068
# 	 Filtered dice     (max): 0.0069
# Image 119
# 	 Found 0 regions in true segmentation.
# 	 Found 2 regions in predicted segmentation.
# 	 Global dice: 0.0000
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 Filtered dice (closest): inf
# 	 Filtered dice     (max): inf
# Image 120
# 	 Found 7 regions in true segmentation.
# 	 Found 15 regions in predicted segmentation.
# 	 Global dice: 0.0099
# 	 0 	Dice (closest): 0.9999 	Dice (max): 0.9999
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0317
# 	 2 	Dice (closest): 0.0253 	Dice (max): 0.0253
# 	 3 	Dice (closest): 0.0431 	Dice (max): 0.0431
# 	 4 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 5 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 6 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 7 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.0168
# 	 Filtered dice     (max): 0.0356
# Image 121
# 	 Found 3 regions in true segmentation.
# 	 Found 1 regions in predicted segmentation.
# 	 Global dice: 0.0000
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 2 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 3 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.0000
# 	 Filtered dice     (max): 0.0000
# Image 122
# 	 Found 24 regions in true segmentation.
# 	 Found 13 regions in predicted segmentation.
# 	 Global dice: 0.0697
# 	 0 	Dice (closest): 0.9997 	Dice (max): 0.9997
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0001
# 	 2 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 3 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 4 	Dice (closest): 0.0000 	Dice (max): 0.0001
# 	 5 	Dice (closest): 0.0000 	Dice (max): 0.0001
# 	 6 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 7 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 8 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 9 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 10 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 11 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 12 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 13 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 14 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 15 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 16 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 17 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 18 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 19 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 20 	Dice (closest): 0.0000 	Dice (max): 0.0001
# 	 21 	Dice (closest): 0.0000 	Dice (max): 0.0001
# 	 22 	Dice (closest): 0.0454 	Dice (max): 0.0454
# 	 23 	Dice (closest): 0.0435 	Dice (max): 0.0435
# 	 24 	Dice (closest): 0.0914 	Dice (max): 0.1020
# 	 Filtered dice (closest): 0.0708
# 	 Filtered dice     (max): 0.0708
# Image 123
# 	 Found 6 regions in true segmentation.
# 	 Found 18 regions in predicted segmentation.
# 	 Global dice: 0.0466
# 	 0 	Dice (closest): 0.9999 	Dice (max): 0.9999
# 	 1 	Dice (closest): 0.0012 	Dice (max): 0.0255
# 	 2 	Dice (closest): 0.0320 	Dice (max): 0.0321
# 	 3 	Dice (closest): 0.1161 	Dice (max): 0.1161
# 	 4 	Dice (closest): 0.0828 	Dice (max): 0.0828
# 	 5 	Dice (closest): 0.1969 	Dice (max): 0.2288
# 	 6 	Dice (closest): 0.4906 	Dice (max): 0.4906
# 	 Filtered dice (closest): 0.0154
# 	 Filtered dice     (max): 0.0377
# Image 124
# 	 Found 14 regions in true segmentation.
# 	 Found 6 regions in predicted segmentation.
# 	 Global dice: 0.7340
# 	 0 	Dice (closest): 0.9998 	Dice (max): 0.9998
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 2 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 3 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 4 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 5 	Dice (closest): 0.7605 	Dice (max): 0.7605
# 	 6 	Dice (closest): 0.7664 	Dice (max): 0.7664
# 	 7 	Dice (closest): 0.4908 	Dice (max): 0.4908
# 	 8 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 9 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 10 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 11 	Dice (closest): 0.7317 	Dice (max): 0.7317
# 	 12 	Dice (closest): 0.7180 	Dice (max): 0.7188
# 	 13 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 14 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.7340
# 	 Filtered dice     (max): 0.7340
# Image 125
# 	 Found 1 regions in true segmentation.
# 	 Found 3 regions in predicted segmentation.
# 	 Global dice: 0.6808
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.7229 	Dice (max): 0.7229
# 	 Filtered dice (closest): 0.7229
# 	 Filtered dice     (max): 0.7229
# Image 126
# 	 Found 1 regions in true segmentation.
# 	 Found 2 regions in predicted segmentation.
# 	 Global dice: 0.1330
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.1330 	Dice (max): 0.1330
# 	 Filtered dice (closest): 0.1330
# 	 Filtered dice     (max): 0.1330
# Image 127
# 	 Found 1 regions in true segmentation.
# 	 Found 2 regions in predicted segmentation.
# 	 Global dice: 0.0000
# 	 0 	Dice (closest): 1.0000 	Dice (max): 1.0000
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.0000
# 	 Filtered dice     (max): 0.0000
# Image 128
# 	 Found 12 regions in true segmentation.
# 	 Found 45 regions in predicted segmentation.
# 	 Global dice: 0.3884
# 	 0 	Dice (closest): 0.9994 	Dice (max): 0.9994
# 	 1 	Dice (closest): 0.2641 	Dice (max): 0.2641
# 	 2 	Dice (closest): 0.0184 	Dice (max): 0.3586
# 	 3 	Dice (closest): 0.0033 	Dice (max): 0.2832
# 	 4 	Dice (closest): 0.0684 	Dice (max): 0.0752
# 	 5 	Dice (closest): 0.0368 	Dice (max): 0.2567
# 	 6 	Dice (closest): 0.6839 	Dice (max): 0.6839
# 	 7 	Dice (closest): 0.6782 	Dice (max): 0.6782
# 	 8 	Dice (closest): 0.0000 	Dice (max): 0.2976
# 	 9 	Dice (closest): 0.0132 	Dice (max): 0.2074
# 	 10 	Dice (closest): 0.4340 	Dice (max): 0.4354
# 	 11 	Dice (closest): 0.0132 	Dice (max): 0.4004
# 	 12 	Dice (closest): 0.0570 	Dice (max): 0.0570
# 	 Filtered dice (closest): 0.2653
# 	 Filtered dice     (max): 0.3569
# Image 129
# 	 Found 10 regions in true segmentation.
# 	 Found 148 regions in predicted segmentation.
# 	 Global dice: 0.3349
# 	 0 	Dice (closest): 0.9912 	Dice (max): 0.9912
# 	 1 	Dice (closest): 0.0025 	Dice (max): 0.0743
# 	 2 	Dice (closest): 0.0059 	Dice (max): 0.0918
# 	 3 	Dice (closest): 0.1099 	Dice (max): 0.1191
# 	 4 	Dice (closest): 0.2606 	Dice (max): 0.2606
# 	 5 	Dice (closest): 0.0023 	Dice (max): 0.2506
# 	 6 	Dice (closest): 0.1966 	Dice (max): 0.2007
# 	 7 	Dice (closest): 0.0111 	Dice (max): 0.0804
# 	 8 	Dice (closest): 0.0027 	Dice (max): 0.0631
# 	 9 	Dice (closest): 0.0114 	Dice (max): 0.0370
# 	 10 	Dice (closest): 0.0332 	Dice (max): 0.0332
# 	 Filtered dice (closest): 0.1112
# 	 Filtered dice     (max): 0.1346
# Image 130
# 	 Found 23 regions in true segmentation.
# 	 Found 59 regions in predicted segmentation.
# 	 Global dice: 0.0354
# 	 0 	Dice (closest): 0.9958 	Dice (max): 0.9958
# 	 1 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 2 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 3 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 4 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 5 	Dice (closest): 0.2590 	Dice (max): 0.2831
# 	 6 	Dice (closest): 0.0305 	Dice (max): 0.2859
# 	 7 	Dice (closest): 0.0016 	Dice (max): 0.0161
# 	 8 	Dice (closest): 0.0016 	Dice (max): 0.0162
# 	 9 	Dice (closest): 0.0017 	Dice (max): 0.1040
# 	 10 	Dice (closest): 0.2897 	Dice (max): 0.2897
# 	 11 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 12 	Dice (closest): 0.0000 	Dice (max): 0.1094
# 	 13 	Dice (closest): 0.2629 	Dice (max): 0.2629
# 	 14 	Dice (closest): 0.6925 	Dice (max): 0.6925
# 	 15 	Dice (closest): 0.6853 	Dice (max): 0.6853
# 	 16 	Dice (closest): 0.5862 	Dice (max): 0.5862
# 	 17 	Dice (closest): 0.0452 	Dice (max): 0.0882
# 	 18 	Dice (closest): 0.0474 	Dice (max): 0.0578
# 	 19 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 20 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 21 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 22 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 23 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 Filtered dice (closest): 0.0061
# 	 Filtered dice     (max): 0.0063

# %%
import time

mtype = modeltypes[0]
print('Model type', mtype)
my_truthlist, my_predlist = get_data(locroot, mtype)

my_truthlist = my_truthlist[:1]
my_predlist  = my_predlist[:1]

start_time = time.time()

print('Calculating Hausdorff distances...')
my_hdist_avg = [None]*len(my_truthlist)
my_hdist_max = [None]*len(my_truthlist)
my_label_sizes = [None]*len(my_truthlist)
my_total_sizes = [None]*len(my_truthlist)
my_dice_scores = [None]*len(my_truthlist)
my_dice_max_scores = [None]*len(my_truthlist)
my_dice_closest_scores = [None]*len(my_truthlist)
my_individual_stats = [None]*len(my_truthlist)
for idx, (tr, pr) in enumerate(zip(my_truthlist, my_predlist)):
    print('Image', idx)
    my_global_scores, my_individual_scores, my_filtered_scores = StatsSITK(tr, pr, idx)
    my_hdist_avg[idx] = my_global_scores[0]
    my_hdist_max[idx] = my_global_scores[1]
    my_dice_scores[idx] = my_global_scores[2]
    my_total_sizes[idx] = my_global_scores[3]
    my_label_sizes[idx] = my_individual_scores['true_vol']
    my_individual_stats[idx] = my_individual_scores
    my_dice_closest_scores[idx] = my_filtered_scores[0]
    my_dice_max_scores[idx] = my_filtered_scores[1]

end_time = time.time()
elapsed = end_time - start_time
print('\nTime elapsed:\t', elapsed)
# Out:
# Model type densenet-pocket
# Found 131 segmentations and predictions...
# Calculating Hausdorff distances...
# Image 0
# 	 Found 11 regions in true segmentation.
# 	 Found 10 regions in predicted segmentation.
# 	 Global dice: 0.3991
# 	 0 	Dice (closest): 0.9999 	Dice (max): 0.9999
# 	 1 	Dice (closest): 0.5699 	Dice (max): 0.5699
# 	 2 	Dice (closest): 0.6416 	Dice (max): 0.6416
# 	 3 	Dice (closest): 0.3314 	Dice (max): 0.3314
# 	 4 	Dice (closest): 0.1847 	Dice (max): 0.4715
# 	 5 	Dice (closest): 0.3483 	Dice (max): 0.3483
# 	 6 	Dice (closest): 0.0000 	Dice (max): 0.2875
# 	 7 	Dice (closest): 0.0000 	Dice (max): 0.0001
# 	 8 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 9 	Dice (closest): 0.0000 	Dice (max): 0.0000
# 	 10 	Dice (closest): 0.3990 	Dice (max): 0.3990
# 	 11 	Dice (closest): 0.6142 	Dice (max): 0.6142
# 	 Filtered dice (closest): 0.0003
# 	 Filtered dice     (max): 0.4220
#
# Time elapsed:	 26.635648250579834

# %%
plt.figure(figsize=(12,4))
plt.scatter(list(range(len(dice_scores))), dice_scores, c='black')
plt.scatter(list(range(len(dice_closest_scores))), dice_closest_scores, c='r')
plt.scatter(list(range(len(dice_max_scores))), dice_max_scores, c='g')
plt.savefig('global-tumor-dice-results.png')
plt.close()
plt.clf()

# %%
plt.figure(figsize=(4,4))
plt.hist(each_tumor_volume, bins=100, range=[0,20000])
plt.savefig('tumor-volume-hist.png')
plt.close()
plt.clf()

# %%
dicediff_closest = np.array(dice_closest_scores) - np.array(dice_scores)
dicediff_max     = np.array(dice_max_scores)     - np.array(dice_scores)

dicediff_closest = dicediff_closest[np.isfinite(dicediff_closest)]
dicediff_max     = dicediff_max[np.isfinite(dicediff_max)]

plt.figure(figsize=(8,4))
ax = plt.subplot(121)
plt.hist(dicediff_closest, bins=50)
ax.set_title('Closest Centroid')
ax = plt.subplot(122)
plt.hist(dicediff_max, bins=50)
ax.set_title('Max Dice')
plt.savefig('global-tumor-dice-difference-filtering.png')
plt.close()
plt.clf()
# Out:
# /opt/apps/miniconda/maskrcnn/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in subtract
#   """Entry point for launching an IPython kernel.
# /opt/apps/miniconda/maskrcnn/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in subtract

# %%
    
# Individual Dice Statistics
each_tumor_dice      = []
each_tumor_dice_max  = []
each_tumor_volume    = []
for idx in range(len(truthlist)):
    if individual_stats[idx] is not None:
        each_tumor_dice      += individual_stats[idx]['closest-dice']
        each_tumor_dice_max  += individual_stats[idx]['max-dice']
        each_tumor_volume    += individual_stats[idx]['true_vol']
print(len(each_tumor_dice))
print(len(each_tumor_volume))
print('Number of zero dice scores:', len([v for v in each_tumor_dice     if v <= 0.01]))
print('Number of zero dice scores:', len([v for v in each_tumor_dice_max if v <= 0.01]))


plt.figure(figsize=(8,4))
ax = plt.subplot(121)
plt.scatter( each_tumor_volume, each_tumor_dice)
ax.set_title('Volume vs. Dice of Closest Centroid')
plt.xlim([0,7.e4])
ax = plt.subplot(122)
plt.scatter( each_tumor_volume, each_tumor_dice_max)
ax.set_title('Volume vs. Dice of Max Predicted Region')
plt.xlim(0,7.e4)
plt.savefig('individual-tumor-dice-results.png')
plt.close()
plt.clf()
# Out:
# 1168
# 1168
# Number of zero dice scores: 548
# Number of zero dice scores: 451

# %%
np_each_tumor_dice = np.array( each_tumor_dice )
np_each_tumor_dice_max = np.array( each_tumor_dice_max )
np_dice_scores = np.array( dice_scores )
np_dice_scores_closest = np.array( dice_closest_scores )
np_dice_scores_max     = np.array( dice_max_scores )

def filter_inf(x):
    x[np.isinf(x)] = 0.0
    return x

np_dice_scores = filter_inf(np_dice_scores)
np_dice_scores_closest = filter_inf(np_dice_scores_closest)
np_dice_scores_max = filter_inf(np_dice_scores_max)

print('Global          \t', np.mean( np_dice_scores), np.std(np_dice_scores))
print('Global - closest\t', np.mean( np_dice_scores_closest), np.std(np_dice_scores_closest))
print('Global -     max\t', np.mean( np_dice_scores_max), np.std(np_dice_scores_max))
print('Tumor  - closest\t', np.mean( np_each_tumor_dice), np.std( np_each_tumor_dice))
print('Tumor  -     max\t', np.mean( np_each_tumor_dice_max), np.std( np_each_tumor_dice_max))
# Out:
# Global          	 0.3126072408876341 0.29612112571082655
# Global - closest	 0.2975849039029823 0.30555854339674854
# Global -     max	 0.30990257631592977 0.30200981273444893
# Tumor  - closest	 0.283695892428425 0.3594167612673872
# Tumor  -     max	 0.3151079232921547 0.3534298500934147

# %%
# filtering for images without tumors        
hdist_avg = [h for h in hdist_avg if h is not None]
hdist_max = [h for h in hdist_max if h is not None]
label_sizes = [l for l in label_sizes if l is not None]
total_sizes = [t for t in total_sizes if t is not None]

# calculating statistics
mean_hdist = sum(hdist_avg) / len(hdist_avg)
max_hdist  = sum(hdist_max) / len(hdist_max)
print('')
print('Hausdorff distances: \t mean:', mean_hdist, '\t max:', max_hdist)
print('Label sizes: \t', label_sizes)

# %%
plt.figure(figsize=(12,4))
ax = plt.subplot(1,3,1)
plt.scatter( total_sizes, hdist_avg)
ax.set_title('Volume vs. Mean Hausdorff')
ax = plt.subplot(1,3,2)
plt.scatter( total_sizes, hdist_max)
ax.set_title('Volume vs. Max Hausdorff')
ax = plt.subplot(1,3,3)
plt.scatter( hdist_avg, hdist_max)
ax.set_title('Mean Hausdorff vs. Max Hausdorff')
plt.show()

# %% [markdown]
# Cells below are to collate results saved to the output.txt files

# %%
def collate_model_comparisons(mtype, locroot='', separate_folds=False):
    print('\ncollating stats for base model', mtype)
    
    textfilelist = glob.glob(locroot+mtype+'/output-005-*.txt')
    print('number of files found:\t', len(textfilelist), '\n')
    
    if separate_folds:
        textfilelist_brokenstrings = [f.split('\\') for f in textfilelist]
    else:
        textfilelist_brokenstrings = [f.split('/') for f in textfilelist]
    textfilelist_dict = {}
    for idx, t in enumerate(textfilelist_brokenstrings):
        try:
            textfilelist_dict[t[0]] += [textfilelist[idx]]
        except:
            textfilelist_dict[t[0]] = [textfilelist[idx]]

    for model in textfilelist_dict:
        print(model)
        scores_dict = gather_test_scores(textfilelist_dict[model])
        plt.figure(figsize=(12,4))
        for idx, metric in enumerate(scores_dict):
            print(metric, np.mean(np.array(scores_dict[metric])), np.std(np.array(scores_dict[metric])))
            ax = plt.subplot(1,3,idx+1)
            plt.hist(scores_dict[metric], range=[0,1], bins=25)
            ax.set_title(metric)
        plt.show()
        print()
    return scores_dict

# %%
archs = ['densenet']
pocket = ['', '-pocket']
modeltypes = []
for a in archs:
    for p in pocket:
        modeltypes += [a+p]

# %%
def initialize_dict(textfile, n_expected=3):
    with open(textfile, 'r') as f:
        linelist = f.readlines()
        testscores = [line for line in linelist if line[0]=='+']
        individual_scores = dict()
        try:
            lines = testscores[:n_expected]
            for l in lines:
                wordlist = l.split()
                name = reduce(lambda x, y: x+' '+y, wordlist[1:-2])
                individual_scores[name] = []
        except:
            print('cannot process file to initialize dict')
        return individual_scores

def process_textfile(textfilelist, score_dict):
    for textfile in textfilelist:
        with open(textfile, 'r') as f:
            linelist = f.readlines()
            testscores = [line for line in linelist if line[0]=='+']
            try:
                for line in testscores:
                    splitline = line.split()
                    name = reduce(lambda x, y: x+' '+y, splitline[1:-2])
                    try:
                        score_dict[name] += [float(splitline[-1])]
                    except:
#                         print('failed to add', name)
                        continue
#                 metrics = [m[1:-2] for m in testscores[0][1:].split()]
#                 assert list(score_dict.keys()) == metrics
#                 for test_img in testscores[2:]:
#                     scores = [float(s[:-1]) for s in test_img[1:].split()]
#                     for i in range(len(metrics)):
#                         score_dict[metrics[i]] += [scores[i]] 
            except:
                print('cannot process file:', textfile)
    return score_dict

def gather_test_scores(textfilelist):
    score_dict = initialize_dict(textfilelist[0])
    return process_textfile(textfilelist, score_dict)

# %%
# modeltypes = ['unet', 'resnet', 'densenet']
results_dict = {}
for mtype in modeltypes:
    results_dict[mtype] = collate_model_comparisons(mtype, separate_folds=False, locroot='../densenet-ensemble-512/')

# %%
plt.figure(figsize=(12,12))
idx = 0
for model in results_dict:
    idx += 1
    metric = list(results_dict[model].keys())[2]
    this_model_results = results_dict[model][metric]
    ax = plt.subplot(3,4,idx)
    plt.boxplot(this_model_results)
    plt.ylim([0,1])
    ax.set_title(model)
plt.savefig('dsc-comp-boxplot.png')
plt.show()

# %%
import scipy
from scipy.stats import wilcoxon, mannwhitneyu

model_names = [('unet', 'unet-pocket'),
               ('resnet', 'resnet-pocket'),
               ('densenet', 'densenet-pocket'),
               ('unet-c2Dt', 'unet-pocket-c2Dt'),
               ('resnet-c2Dt', 'resnet-pocket-c2Dt'),
               ('densenet-c2Dt', 'densenet-pocket-c2Dt')]
for model in model_names:
    print('Testing', model[0], 'vs.', model[1])
    metric = list(results_dict[model[0]].keys())[2]
    this_model_results_base = results_dict[model[0]][metric]
    this_model_results_pocket = results_dict[model[1]][metric]
    diff = [r1 - r2 for r1, r2 in zip(this_model_results_base, this_model_results_pocket)]
    wiltest = wilcoxon(diff, correction=True)
    mwtest  = mannwhitneyu(this_model_results_base, this_model_results_pocket)
    print(wiltest2, len(diff))
    print(mwtest,   len(diff))
    print('\n')

# %%
this_model_results_base
